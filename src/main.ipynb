# %% [markdown]
# # Multilingual Stance Detection on Twitter

# %%
# %run src/libraries.ipynb
# %run src/data_preprocessing.ipynb
# %run src/utilities.ipynb
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting git+https://github.com/huggingface/transformers
#   Cloning https://github.com/huggingface/transformers to /tmp/pip-req-build-u8iqyvji
#   Running command git clone -q https://github.com/huggingface/transformers /tmp/pip-req-build-u8iqyvji
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#     Preparing wheel metadata ... done
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.7/dist-packages (from transformers==4.22.0.dev0) (4.64.0)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.7/dist-packages (from transformers==4.22.0.dev0) (2022.6.2)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.7/dist-packages (from transformers==4.22.0.dev0) (1.21.6)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from transformers==4.22.0.dev0) (4.12.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.7/dist-packages (from transformers==4.22.0.dev0) (3.8.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.8.1 in /usr/local/lib/python3.7/dist-packages (from transformers==4.22.0.dev0) (0.9.1)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.7/dist-packages (from transformers==4.22.0.dev0) (21.3)
# Requirement already satisfied: tokenizers!=0.11.3,<0.13,>=0.11.1 in /usr/local/lib/python3.7/dist-packages (from transformers==4.22.0.dev0) (0.12.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from transformers==4.22.0.dev0) (2.23.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.7/dist-packages (from transformers==4.22.0.dev0) (6.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.7/dist-packages (from huggingface-hub<1.0,>=0.8.1->transformers==4.22.0.dev0) (4.1.1)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging>=20.0->transformers==4.22.0.dev0) (3.0.9)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->transformers==4.22.0.dev0) (3.8.1)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->transformers==4.22.0.dev0) (2022.6.15)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->transformers==4.22.0.dev0) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->transformers==4.22.0.dev0) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->transformers==4.22.0.dev0) (1.25.11)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: tweet-preprocessor in /usr/local/lib/python3.7/dist-packages (0.6.0)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: datasets in /usr/local/lib/python3.7/dist-packages (2.4.0)
# Requirement already satisfied: tqdm>=4.62.1 in /usr/local/lib/python3.7/dist-packages (from datasets) (4.64.0)
# Requirement already satisfied: pyarrow>=6.0.0 in /usr/local/lib/python3.7/dist-packages (from datasets) (6.0.1)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.7/dist-packages (from datasets) (1.21.6)
# Requirement already satisfied: fsspec[http]>=2021.11.1 in /usr/local/lib/python3.7/dist-packages (from datasets) (2022.7.1)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.7/dist-packages (from datasets) (3.0.0)
# Requirement already satisfied: dill<0.3.6 in /usr/local/lib/python3.7/dist-packages (from datasets) (0.3.5.1)
# Requirement already satisfied: multiprocess in /usr/local/lib/python3.7/dist-packages (from datasets) (0.70.13)
# Requirement already satisfied: packaging in /usr/local/lib/python3.7/dist-packages (from datasets) (21.3)
# Requirement already satisfied: responses<0.19 in /usr/local/lib/python3.7/dist-packages (from datasets) (0.18.0)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from datasets) (4.12.0)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.7/dist-packages (from datasets) (3.8.1)
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.7/dist-packages (from datasets) (2.23.0)
# Requirement already satisfied: huggingface-hub<1.0.0,>=0.1.0 in /usr/local/lib/python3.7/dist-packages (from datasets) (0.9.1)
# Requirement already satisfied: pandas in /usr/local/lib/python3.7/dist-packages (from datasets) (1.3.5)
# Requirement already satisfied: filelock in /usr/local/lib/python3.7/dist-packages (from huggingface-hub<1.0.0,>=0.1.0->datasets) (3.8.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.7/dist-packages (from huggingface-hub<1.0.0,>=0.1.0->datasets) (4.1.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.7/dist-packages (from huggingface-hub<1.0.0,>=0.1.0->datasets) (6.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging->datasets) (3.0.9)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests>=2.19.0->datasets) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests>=2.19.0->datasets) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests>=2.19.0->datasets) (2022.6.15)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests>=2.19.0->datasets) (1.25.11)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.7/dist-packages (from aiohttp->datasets) (6.0.2)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.7/dist-packages (from aiohttp->datasets) (1.8.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.7/dist-packages (from aiohttp->datasets) (1.2.0)
# Requirement already satisfied: asynctest==0.13.0 in /usr/local/lib/python3.7/dist-packages (from aiohttp->datasets) (0.13.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.7/dist-packages (from aiohttp->datasets) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.7/dist-packages (from aiohttp->datasets) (22.1.0)
# Requirement already satisfied: charset-normalizer<3.0,>=2.0 in /usr/local/lib/python3.7/dist-packages (from aiohttp->datasets) (2.1.0)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /usr/local/lib/python3.7/dist-packages (from aiohttp->datasets) (4.0.2)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->datasets) (3.8.1)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.7/dist-packages (from pandas->datasets) (2022.2.1)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas->datasets) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas->datasets) (1.15.0)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: tensorflow_text in /usr/local/lib/python3.7/dist-packages (2.9.0)
# Requirement already satisfied: tensorflow<2.10,>=2.9.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow_text) (2.9.1)
# Requirement already satisfied: tensorflow-hub>=0.8.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow_text) (0.12.0)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow<2.10,>=2.9.0->tensorflow_text) (0.26.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.7/dist-packages (from tensorflow<2.10,>=2.9.0->tensorflow_text) (21.3)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.7/dist-packages (from tensorflow<2.10,>=2.9.0->tensorflow_text) (3.3.0)
# Requirement already satisfied: flatbuffers<2,>=1.12 in /usr/local/lib/python3.7/dist-packages (from tensorflow<2.10,>=2.9.0->tensorflow_text) (1.12)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow<2.10,>=2.9.0->tensorflow_text) (1.6.3)
# Requirement already satisfied: tensorboard<2.10,>=2.9 in /usr/local/lib/python3.7/dist-packages (from tensorflow<2.10,>=2.9.0->tensorflow_text) (2.9.1)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow<2.10,>=2.9.0->tensorflow_text) (1.1.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.7/dist-packages (from tensorflow<2.10,>=2.9.0->tensorflow_text) (1.47.0)
# Requirement already satisfied: keras-preprocessing>=1.1.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow<2.10,>=2.9.0->tensorflow_text) (1.1.2)
# Requirement already satisfied: protobuf<3.20,>=3.9.2 in /usr/local/lib/python3.7/dist-packages (from tensorflow<2.10,>=2.9.0->tensorflow_text) (3.17.3)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow<2.10,>=2.9.0->tensorflow_text) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow<2.10,>=2.9.0->tensorflow_text) (14.0.6)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from tensorflow<2.10,>=2.9.0->tensorflow_text) (57.4.0)
# Requirement already satisfied: gast<=0.4.0,>=0.2.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow<2.10,>=2.9.0->tensorflow_text) (0.4.0)
# Requirement already satisfied: numpy>=1.20 in /usr/local/lib/python3.7/dist-packages (from tensorflow<2.10,>=2.9.0->tensorflow_text) (1.21.6)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.7/dist-packages (from tensorflow<2.10,>=2.9.0->tensorflow_text) (4.1.1)
# Requirement already satisfied: keras<2.10.0,>=2.9.0rc0 in /usr/local/lib/python3.7/dist-packages (from tensorflow<2.10,>=2.9.0->tensorflow_text) (2.9.0)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow<2.10,>=2.9.0->tensorflow_text) (1.15.0)
# Requirement already satisfied: h5py>=2.9.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow<2.10,>=2.9.0->tensorflow_text) (3.1.0)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow<2.10,>=2.9.0->tensorflow_text) (1.14.1)
# Requirement already satisfied: tensorflow-estimator<2.10.0,>=2.9.0rc0 in /usr/local/lib/python3.7/dist-packages (from tensorflow<2.10,>=2.9.0->tensorflow_text) (2.9.0)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow<2.10,>=2.9.0->tensorflow_text) (1.2.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.7/dist-packages (from astunparse>=1.6.0->tensorflow<2.10,>=2.9.0->tensorflow_text) (0.37.1)
# Requirement already satisfied: cached-property in /usr/local/lib/python3.7/dist-packages (from h5py>=2.9.0->tensorflow<2.10,>=2.9.0->tensorflow_text) (1.5.2)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.10,>=2.9->tensorflow<2.10,>=2.9.0->tensorflow_text) (0.6.1)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.10,>=2.9->tensorflow<2.10,>=2.9.0->tensorflow_text) (0.4.6)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.10,>=2.9->tensorflow<2.10,>=2.9.0->tensorflow_text) (3.4.1)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.10,>=2.9->tensorflow<2.10,>=2.9.0->tensorflow_text) (1.8.1)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.10,>=2.9->tensorflow<2.10,>=2.9.0->tensorflow_text) (2.23.0)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.10,>=2.9->tensorflow<2.10,>=2.9.0->tensorflow_text) (1.0.1)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.10,>=2.9->tensorflow<2.10,>=2.9.0->tensorflow_text) (1.35.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.7/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.10,>=2.9->tensorflow<2.10,>=2.9.0->tensorflow_text) (4.9)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.7/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.10,>=2.9->tensorflow<2.10,>=2.9.0->tensorflow_text) (0.2.8)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.10,>=2.9->tensorflow<2.10,>=2.9.0->tensorflow_text) (4.2.4)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.7/dist-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.10,>=2.9->tensorflow<2.10,>=2.9.0->tensorflow_text) (1.3.1)
# Requirement already satisfied: importlib-metadata>=4.4 in /usr/local/lib/python3.7/dist-packages (from markdown>=2.6.8->tensorboard<2.10,>=2.9->tensorflow<2.10,>=2.9.0->tensorflow_text) (4.12.0)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard<2.10,>=2.9->tensorflow<2.10,>=2.9.0->tensorflow_text) (3.8.1)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /usr/local/lib/python3.7/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.10,>=2.9->tensorflow<2.10,>=2.9.0->tensorflow_text) (0.4.8)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.21.0->tensorboard<2.10,>=2.9->tensorflow<2.10,>=2.9.0->tensorflow_text) (2022.6.15)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.21.0->tensorboard<2.10,>=2.9->tensorflow<2.10,>=2.9.0->tensorflow_text) (1.25.11)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.21.0->tensorboard<2.10,>=2.9->tensorflow<2.10,>=2.9.0->tensorflow_text) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.21.0->tensorboard<2.10,>=2.9->tensorflow<2.10,>=2.9.0->tensorflow_text) (2.10)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.7/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.10,>=2.9->tensorflow<2.10,>=2.9.0->tensorflow_text) (3.2.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging->tensorflow<2.10,>=2.9.0->tensorflow_text) (3.0.9)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: sacremoses in /usr/local/lib/python3.7/dist-packages (0.0.53)
# Requirement already satisfied: click in /usr/local/lib/python3.7/dist-packages (from sacremoses) (7.1.2)
# Requirement already satisfied: regex in /usr/local/lib/python3.7/dist-packages (from sacremoses) (2022.6.2)
# Requirement already satisfied: joblib in /usr/local/lib/python3.7/dist-packages (from sacremoses) (1.1.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.7/dist-packages (from sacremoses) (4.64.0)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from sacremoses) (1.15.0)
# There are 1 GPU(s) available.
# We will use the GPU: Tesla T4
# total number of records 13834
# Stance bifurcation Counter({'FAVOR': 6631, 'AGAINST': 4504, 'NEUTRAL': 2699})
# total number of records 13834
# Stance bifurcation Counter({'FAVOR': 6631, 'AGAINST': 4504, 'NEUTRAL': 2699})
# total number of records 13834
# Stance bifurcation Counter({'SP': 5545, 'CA': 4649, 'EN': 1691, 'FR': 1116, 'IT': 833})
# total number of records 13834
# Stance bifurcation Counter({'FAVOR': 6631, 'AGAINST': 4504, 'NEUTRAL': 2699})
# total number of records 1691
# Stance bifurcation Counter({'AGAINST': 864, 'NEUTRAL': 516, 'FAVOR': 311})
#             Target Language  AGAINST  FAVOR  NEUTRAL
# 0     Donald Trump       EN      299    148      260
# 1  Hillary Clinton       EN      565    163      256
#
#
# total number of records 1691
# Stance bifurcation Counter({'AGAINST': 864, 'NEUTRAL': 516, 'FAVOR': 311})
#             Target  AGAINST  FAVOR  NEUTRAL
# 0     Donald Trump      299    148      260
# 1  Hillary Clinton      565    163      256
# total number of records 1691
# Stance bifurcation Counter({'AGAINST': 864, 'NEUTRAL': 516, 'FAVOR': 311})
#   Language  AGAINST  FAVOR  NEUTRAL
# 0       EN      864    311      516
# total number of records 10194
# Stance bifurcation Counter({'FAVOR': 6001, 'AGAINST': 2380, 'NEUTRAL': 1813})
#                     Target Language  AGAINST  FAVOR  NEUTRAL
# 0  Catalonian Independence       CA      149   3902      598
# 1  Catalonian Independence       SP     2231   2099     1215
#
#
# total number of records 10194
# Stance bifurcation Counter({'FAVOR': 6001, 'AGAINST': 2380, 'NEUTRAL': 1813})
#                     Target  AGAINST  FAVOR  NEUTRAL
# 0  Catalonian Independence     2380   6001     1813
#
#
# total number of records 10194
# Stance bifurcation Counter({'FAVOR': 6001, 'AGAINST': 2380, 'NEUTRAL': 1813})
#   Language  AGAINST  FAVOR  NEUTRAL
# 0       CA      149   3902      598
# 1       SP     2231   2099     1215
# total number of records 10194
# Stance bifurcation Counter({'FAVOR': 6001, 'AGAINST': 2380, 'NEUTRAL': 1813})
#                     Target  AGAINST  FAVOR  NEUTRAL
# 0  Catalonian Independence     2380   6001     1813
# total number of records 1116
# Stance bifurcation Counter({'AGAINST': 774, 'NEUTRAL': 186, 'FAVOR': 156})
#             Target  AGAINST  FAVOR  NEUTRAL
# 0  Emmanuel Macron      308     91      131
# 1    Marine Le Pen      466     65       55
# total number of records 833
# Stance bifurcation Counter({'AGAINST': 486, 'NEUTRAL': 184, 'FAVOR': 163})
#                   Target  AGAINST  FAVOR  NEUTRAL
# 0  Constitutional Reform      486    163      184
# Train Data Counter({'FAVOR': 5302, 'AGAINST': 3601, 'NEUTRAL': 2157})
# test Data Counter({'FAVOR': 1329, 'AGAINST': 903, 'NEUTRAL': 542})
# Train Data Counter({'FAVOR': 3975, 'AGAINST': 2700, 'NEUTRAL': 1617})
# val Data Counter({'FAVOR': 1327, 'AGAINST': 901, 'NEUTRAL': 540})
# training set contains 8292 number of tweets
# validation set contains 2768 number of tweets
# test set contains 2774 number of tweets
# Train Data Counter({'FAVOR': 3975, 'AGAINST': 2700, 'NEUTRAL': 1617})
# Validation Data Counter({'FAVOR': 1327, 'AGAINST': 901, 'NEUTRAL': 540})
# Test Data Counter({'FAVOR': 1329, 'AGAINST': 903, 'NEUTRAL': 542})
# 8292
# 11060
# total number of records 8292
# Stance bifurcation Counter({'FAVOR': 3975, 'AGAINST': 2700, 'NEUTRAL': 1617})
#   Language  AGAINST  FAVOR  NEUTRAL
# 0       CA       89   2340      358
# 1       EN      518    186      309
# 2       FR      464     93      111
# 3       IT      291     97      110
# 4       SP     1338   1259      729
# total number of records 2768
# Stance bifurcation Counter({'FAVOR': 1327, 'AGAINST': 901, 'NEUTRAL': 540})
#   Language  AGAINST  FAVOR  NEUTRAL
# 0       CA       30    781      120
# 1       EN      173     62      103
# 2       FR      155     31       37
# 3       IT       97     33       37
# 4       SP      446    420      243
# total number of records 2774
# Stance bifurcation Counter({'FAVOR': 1329, 'AGAINST': 903, 'NEUTRAL': 542})
#   Language  AGAINST  FAVOR  NEUTRAL
# 0       CA       30    781      120
# 1       EN      173     63      104
# 2       FR      155     32       38
# 3       IT       98     33       37
# 4       SP      447    420      243
# French Training set contains  668
# English Training set contains  1013
# Spanish Training set contains  3326
# Catalan Training set contains  2787
# Italian Training set contains  498
# French Validation set contains  223
# English Validation set contains  338
# Spanish Validation set contains  1109
# Catalan Validation set contains  931
# Italian Validation set contains  167
# French Test set contains  225
# English Test set contains  340
# Spanish Test set contains  1110
# Catalan Test set contains  931
# Italian Test set contains  168
# total number of records 3326
# Stance bifurcation Counter({'AGAINST': 1338, 'FAVOR': 1259, 'NEUTRAL': 729})
#   Language  AGAINST  FAVOR  NEUTRAL
# 0       SP     1338   1259      729
# total number of records 1109
# Stance bifurcation Counter({'AGAINST': 446, 'FAVOR': 420, 'NEUTRAL': 243})
#   Language  AGAINST  FAVOR  NEUTRAL
# 0       SP      446    420      243
# total number of records 1110
# Stance bifurcation Counter({'AGAINST': 447, 'FAVOR': 420, 'NEUTRAL': 243})
#   Language  AGAINST  FAVOR  NEUTRAL
# 0       SP      447    420      243
# total number of records 1013
# Stance bifurcation Counter({'AGAINST': 518, 'NEUTRAL': 309, 'FAVOR': 186})
#   Language  AGAINST  FAVOR  NEUTRAL
# 0       EN      518    186      309
# total number of records 338
# Stance bifurcation Counter({'AGAINST': 173, 'NEUTRAL': 103, 'FAVOR': 62})
#   Language  AGAINST  FAVOR  NEUTRAL
# 0       EN      173     62      103
# total number of records 340
# Stance bifurcation Counter({'AGAINST': 173, 'NEUTRAL': 104, 'FAVOR': 63})
#   Language  AGAINST  FAVOR  NEUTRAL
# 0       EN      173     63      104
# total number of records 2787
# Stance bifurcation Counter({'FAVOR': 2340, 'NEUTRAL': 358, 'AGAINST': 89})
#   Language  AGAINST  FAVOR  NEUTRAL
# 0       CA       89   2340      358
# total number of records 931
# Stance bifurcation Counter({'FAVOR': 781, 'NEUTRAL': 120, 'AGAINST': 30})
#   Language  AGAINST  FAVOR  NEUTRAL
# 0       CA       30    781      120
# total number of records 931
# Stance bifurcation Counter({'FAVOR': 781, 'NEUTRAL': 120, 'AGAINST': 30})
#   Language  AGAINST  FAVOR  NEUTRAL
# 0       CA       30    781      120
# total number of records 668
# Stance bifurcation Counter({'AGAINST': 464, 'NEUTRAL': 111, 'FAVOR': 93})
#   Language  AGAINST  FAVOR  NEUTRAL
# 0       FR      464     93      111
# total number of records 223
# Stance bifurcation Counter({'AGAINST': 155, 'NEUTRAL': 37, 'FAVOR': 31})
#   Language  AGAINST  FAVOR  NEUTRAL
# 0       FR      155     31       37
# total number of records 225
# Stance bifurcation Counter({'AGAINST': 155, 'NEUTRAL': 38, 'FAVOR': 32})
#   Language  AGAINST  FAVOR  NEUTRAL
# 0       FR      155     32       38
# total number of records 498
# Stance bifurcation Counter({'AGAINST': 291, 'NEUTRAL': 110, 'FAVOR': 97})
#   Language  AGAINST  FAVOR  NEUTRAL
# 0       IT      291     97      110
# total number of records 167
# Stance bifurcation Counter({'AGAINST': 97, 'NEUTRAL': 37, 'FAVOR': 33})
#   Language  AGAINST  FAVOR  NEUTRAL
# 0       IT       97     33       37
# total number of records 168
# Stance bifurcation Counter({'AGAINST': 98, 'NEUTRAL': 37, 'FAVOR': 33})
#   Language  AGAINST  FAVOR  NEUTRAL
# 0       IT       98     33       37
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %% [markdown]
# ## SVM+TFIDF - English

# %%
input_C=100
input_gamma=0.01
# %run src/model/SVM/SVM+TFIDF_EN.ipynb
# Out:
# Evaluation for: English : SVC with TfidfVectorizer: Validation set
#               precision    recall  f1-score   support
#
#      AGAINST      0.598     0.688     0.640       173
#        FAVOR      0.537     0.468     0.500        62
#      NEUTRAL      0.529     0.437     0.479       103
#
#     accuracy                          0.571       338
#    macro avg      0.555     0.531     0.540       338
# weighted avg      0.566     0.571     0.565       338
# Evaluation for: English : SVC with TfidfVectorizer: Test set
#               precision    recall  f1-score   support
#
#      AGAINST      0.606     0.746     0.668       173
#        FAVOR      0.480     0.381     0.425        63
#      NEUTRAL      0.675     0.500     0.575       104
#
#     accuracy                          0.603       340
#    macro avg      0.587     0.542     0.556       340
# weighted avg      0.604     0.603     0.595       340
# Micro Average Precision :  0.6029411764705882
# Micro Average Recall :  0.6029411764705882
# Micro Average F1-Score :  0.6029411764705882
# ............................
# Macro Average Precision :  0.5869861593805256
# Macro Average Recall :  0.5422057069455913
# Macro Average F1-Score :  0.5559193929348275

# %% [markdown]
# ## SVM + TFIDF - Spanish

# %%
input_C=100
input_gamma=0.1
# %run src/model/SVM/SVM+TFIDF_SP.ipynb
# Out:
# Evaluation for: Spanish : SVC with TfidfVectorizer: Validation set
#               precision    recall  f1-score   support
#
#      AGAINST      0.695     0.726     0.711       446
#        FAVOR      0.689     0.748     0.717       420
#      NEUTRAL      0.914     0.704     0.795       243
#
#     accuracy                          0.729      1109
#    macro avg      0.766     0.726     0.741      1109
# weighted avg      0.741     0.729     0.732      1109
# Evaluation for: Spanish : SVC with TfidfVectorizer: Test set
#               precision    recall  f1-score   support
#
#      AGAINST      0.648     0.705     0.675       447
#        FAVOR      0.652     0.683     0.667       420
#      NEUTRAL      0.859     0.650     0.740       243
#
#     accuracy                          0.685      1110
#    macro avg      0.720     0.679     0.694      1110
# weighted avg      0.696     0.685     0.686      1110
# Micro Average Precision :  0.6846846846846847
# Micro Average Recall :  0.6846846846846847
# Micro Average F1-Score :  0.6846846846846847
# ............................
# Macro Average Precision :  0.7197055091982628
# Macro Average Recall :  0.679412360409129
# Macro Average F1-Score :  0.6942432854762935

# %% [markdown]
# ## SVM + TFIDF - Catalan

# %%
input_C=100
input_gamma=0.01
# %run src/model/SVM/SVM+TFIDF_CA.ipynb
# Out:
# Evaluation for: Catalan : SVC with TfidfVectorizer: Validation set
#               precision    recall  f1-score   support
#
#      AGAINST      1.000     0.067     0.125        30
#        FAVOR      0.892     0.974     0.931       781
#      NEUTRAL      0.724     0.458     0.561       120
#
#     accuracy                          0.879       931
#    macro avg      0.872     0.500     0.539       931
# weighted avg      0.874     0.879     0.858       931
# Evaluation for: Catalan : SVC with TfidfVectorizer: Test set
#               precision    recall  f1-score   support
#
#      AGAINST      0.000     0.000     0.000        30
#        FAVOR      0.893     0.978     0.933       781
#      NEUTRAL      0.757     0.467     0.577       120
#
#     accuracy                          0.881       931
#    macro avg      0.550     0.482     0.504       931
# weighted avg      0.846     0.881     0.857       931
# Micro Average Precision :  0.8807733619763695
# Micro Average Recall :  0.8807733619763695
# Micro Average F1-Score :  0.8807733619763695
# ............................
# Macro Average Precision :  0.5497600404142461
# Macro Average Recall :  0.4816332337459098
# Macro Average F1-Score :  0.5035781235895854

# %% [markdown]
# ## SVM + TFIDF - French

# %%
input_C=100
input_gamma=0.01
# %run src/model/SVM/SVM+TFIDF_FR.ipynb
# Out:
# Evaluation for: French : SVC with TfidfVectorizer: Validation set
#               precision    recall  f1-score   support
#
#      AGAINST      0.783     0.884     0.830       155
#        FAVOR      0.261     0.194     0.222        31
#      NEUTRAL      0.640     0.432     0.516        37
#
#     accuracy                          0.713       223
#    macro avg      0.561     0.503     0.523       223
# weighted avg      0.687     0.713     0.694       223
# Evaluation for: French : SVC with TfidfVectorizer: Test set
#               precision    recall  f1-score   support
#
#      AGAINST      0.766     0.910     0.832       155
#        FAVOR      0.250     0.094     0.136        32
#      NEUTRAL      0.552     0.421     0.478        38
#
#     accuracy                          0.711       225
#    macro avg      0.523     0.475     0.482       225
# weighted avg      0.657     0.711     0.673       225
# Micro Average Precision :  0.7111111111111111
# Micro Average Recall :  0.7111111111111111
# Micro Average F1-Score :  0.7111111111111111
# ............................
# Macro Average Precision :  0.5226761619190404
# Macro Average Recall :  0.47482668364459535
# Macro Average F1-Score :  0.48194466124726326

# %% [markdown]
# ## SVM + TFIDF - Italian

# %%
input_C=100
input_gamma=0.01
# %run src/model/SVM/SVM+TFIDF_IT.ipynb
# Out:
# Evaluation for: Italian : SVC with TfidfVectorizer: Validation set
#               precision    recall  f1-score   support
#
#      AGAINST      0.906     0.990     0.946        97
#        FAVOR      0.912     0.939     0.925        33
#      NEUTRAL      0.926     0.676     0.781        37
#
#     accuracy                          0.910       167
#    macro avg      0.914     0.868     0.884       167
# weighted avg      0.911     0.910     0.905       167
# Evaluation for: Italian : SVC with TfidfVectorizer: Test set
#               precision    recall  f1-score   support
#
#      AGAINST      0.865     0.980     0.919        98
#        FAVOR      0.964     0.818     0.885        33
#      NEUTRAL      0.931     0.730     0.818        37
#
#     accuracy                          0.893       168
#    macro avg      0.920     0.843     0.874       168
# weighted avg      0.899     0.893     0.890       168
# Micro Average Precision :  0.8928571428571429
# Micro Average Recall :  0.8928571428571429
# Micro Average F1-Score :  0.8928571428571429
# ............................
# Macro Average Precision :  0.9200616873030666
# Macro Average Recall :  0.8425011282154139
# Macro Average F1-Score :  0.8740293356341674

# %% [markdown]
# ## LR + TFIDF- English

# %%
input_C=100
# %run src/model/LR/LR+TFIDF_EN.ipynb
# Out:
# Evaluation for: English : LR with TF-IDF Vectorizer - Validation set
#               precision    recall  f1-score   support
#
#      AGAINST      0.608     0.699     0.651       173
#        FAVOR      0.554     0.500     0.525        62
#      NEUTRAL      0.542     0.437     0.484       103
#
#     accuracy                          0.583       338
#    macro avg      0.568     0.545     0.553       338
# weighted avg      0.578     0.583     0.577       338
# Evaluation for: English : LR with TF-IDF Vectorizer - Test set
#               precision    recall  f1-score   support
#
#      AGAINST      0.617     0.746     0.675       173
#        FAVOR      0.547     0.460     0.500        63
#      NEUTRAL      0.641     0.481     0.549       104
#
#     accuracy                          0.612       340
#    macro avg      0.602     0.562     0.575       340
# weighted avg      0.612     0.612     0.604       340
# Micro Average Precision :  0.611764705882353
# Micro Average Recall :  0.611764705882353
# Micro Average F1-Score :  0.611764705882353
# ............................
# Macro Average Precision :  0.6018067775763902
# Macro Average Recall :  0.5622504769903615
# Macro Average F1-Score :  0.5749477398692059

# %% [markdown]
# ## LR + TFIDF- Spanish

# %%
input_C=10
# %run src/model/LR/LR+TFIDF_SP.ipynb
# Out:
# Evaluation for: Spanish : LR with TF-IDF Vectorizer - Validation set
#               precision    recall  f1-score   support
#
#      AGAINST      0.703     0.749     0.725       446
#        FAVOR      0.697     0.755     0.725       420
#      NEUTRAL      0.933     0.687     0.791       243
#
#     accuracy                          0.738      1109
#    macro avg      0.778     0.730     0.747      1109
# weighted avg      0.751     0.738     0.740      1109
# Evaluation for: Spanish : LR with TF-IDF Vectorizer - Test set
#               precision    recall  f1-score   support
#
#      AGAINST      0.665     0.732     0.696       447
#        FAVOR      0.659     0.695     0.677       420
#      NEUTRAL      0.891     0.642     0.746       243
#
#     accuracy                          0.698      1110
#    macro avg      0.738     0.690     0.707      1110
# weighted avg      0.712     0.698     0.700      1110
# Micro Average Precision :  0.6981981981981982
# Micro Average Recall :  0.6981981981981982
# Micro Average F1-Score :  0.6981981981981982
# ............................
# Macro Average Precision :  0.7384016433198837
# Macro Average Recall :  0.6895856760137148
# Macro Average F1-Score :  0.7065354201234469

# %% [markdown]
# ## LR + TFIDF- Catalan

# %%
input_C=100
# %run src/model/LR/LR+TFIDF_CA.ipynb
# Out:
# Evaluation for: Catalan : LR with TF-IDF Vectorizer - Validation set
#               precision    recall  f1-score   support
#
#      AGAINST      0.000     0.000     0.000        30
#        FAVOR      0.884     0.982     0.930       781
#      NEUTRAL      0.762     0.400     0.525       120
#
#     accuracy                          0.875       931
#    macro avg      0.549     0.461     0.485       931
# weighted avg      0.839     0.875     0.848       931
# Evaluation for: Catalan : LR with TF-IDF Vectorizer - Test set
#               precision    recall  f1-score   support
#
#      AGAINST      0.000     0.000     0.000        30
#        FAVOR      0.890     0.980     0.932       781
#      NEUTRAL      0.757     0.442     0.558       120
#
#     accuracy                          0.879       931
#    macro avg      0.549     0.474     0.497       931
# weighted avg      0.844     0.879     0.854       931
# Micro Average Precision :  0.878625134264232
# Micro Average Recall :  0.878625134264232
# Micro Average F1-Score :  0.8786251342642319
# ............................
# Macro Average Precision :  0.5488925802879291
# Macro Average Recall :  0.4737267036562811
# Macro Average F1-Score :  0.49675101831360857

# %% [markdown]
# ## LR + TFIDF- French

# %%
input_C=100
# %run src/model/LR/LR+TFIDF_FR.ipynb
# Out:
# Evaluation for: French : LR with TF-IDF Vectorizer - Validation set
#               precision    recall  f1-score   support
#
#      AGAINST      0.791     0.929     0.855       155
#        FAVOR      0.421     0.258     0.320        31
#      NEUTRAL      0.682     0.405     0.508        37
#
#     accuracy                          0.749       223
#    macro avg      0.631     0.531     0.561       223
# weighted avg      0.722     0.749     0.723       223
# Evaluation for: French : LR with TF-IDF Vectorizer - Test set
#               precision    recall  f1-score   support
#
#      AGAINST      0.754     0.890     0.817       155
#        FAVOR      0.167     0.062     0.091        32
#      NEUTRAL      0.533     0.421     0.471        38
#
#     accuracy                          0.693       225
#    macro avg      0.485     0.458     0.459       225
# weighted avg      0.633     0.693     0.655       225
# Micro Average Precision :  0.6933333333333334
# Micro Average Recall :  0.6933333333333334
# Micro Average F1-Score :  0.6933333333333334
# ............................
# Macro Average Precision :  0.4846994535519125
# Macro Average Recall :  0.4579584040747029
# Macro Average F1-Score :  0.4593551245134955

# %% [markdown]
# ## LR + TFIDF- Italian

# %%
input_C=100
# %run src/model/LR/LR+TFIDF_IT.ipynb
# Out:
# Evaluation for: Italian : LR with TF-IDF Vectorizer - Validation set
#               precision    recall  f1-score   support
#
#      AGAINST      0.865     0.990     0.923        97
#        FAVOR      0.912     0.939     0.925        33
#      NEUTRAL      0.955     0.568     0.712        37
#
#     accuracy                          0.886       167
#    macro avg      0.910     0.832     0.853       167
# weighted avg      0.894     0.886     0.877       167
# Evaluation for: Italian : LR with TF-IDF Vectorizer - Test set
#               precision    recall  f1-score   support
#
#      AGAINST      0.881     0.980     0.928        98
#        FAVOR      0.963     0.788     0.867        33
#      NEUTRAL      0.906     0.784     0.841        37
#
#     accuracy                          0.899       168
#    macro avg      0.917     0.850     0.878       168
# weighted avg      0.903     0.899     0.896       168
# Micro Average Precision :  0.8988095238095238
# Micro Average Recall :  0.8988095238095238
# Micro Average F1-Score :  0.8988095238095238
# ............................
# Macro Average Precision :  0.9166489693056971
# Macro Average Recall :  0.8504181361324218
# Macro Average F1-Score :  0.8782608695652172

# %% [markdown]
# # SVM + MUSE

# %%
input_C=100
input_gamma = 1
# %run src/model/SVM/SVM+MUSE.ipynb
# Out:
# 100%|██████████| 8292/8292 [02:37<00:00, 52.64it/s]
# 100%|██████████| 2768/2768 [00:52<00:00, 52.67it/s]
# 100%|██████████| 2774/2774 [00:51<00:00, 53.99it/s]
# Evaluation for: SVC Classifier with Multilingual Encoding : Validation
#               precision    recall  f1-score   support
#
#      AGAINST      0.645     0.694     0.668       901
#        FAVOR      0.782     0.775     0.779      1327
#      NEUTRAL      0.692     0.619     0.653       540
#
#     accuracy                          0.718      2768
#    macro avg      0.706     0.696     0.700      2768
# weighted avg      0.720     0.718     0.718      2768
# Evaluation for: SVC Classifier with Multilingual Encoding : Test
#               precision    recall  f1-score   support
#
#      AGAINST      0.632     0.691     0.660       903
#        FAVOR      0.769     0.750     0.759      1329
#      NEUTRAL      0.685     0.618     0.650       542
#
#     accuracy                          0.705      2774
#    macro avg      0.695     0.686     0.690      2774
# weighted avg      0.708     0.705     0.706      2774
# Micro Average Precision :  0.7051189617880317
# Micro Average Recall :  0.7051189617880317
# Micro Average F1-Score :  0.7051189617880317
# ............................
# Macro Average Precision :  0.6951158383571525
# Macro Average Recall :  0.6864330641686535
# Macro Average F1-Score :  0.6897175200240867

# %% [markdown]
# # LR + MUSE

# %%
input_C=1
# %run src/model/LR/LR+MUSE.ipynb
# Out:
# 100%|██████████| 8292/8292 [02:31<00:00, 54.66it/s]
# 100%|██████████| 2768/2768 [00:51<00:00, 54.22it/s]
# 100%|██████████| 2774/2774 [00:50<00:00, 55.41it/s]
# Evaluation for: LR with Multilingual Encoding : Validation
#               precision    recall  f1-score   support
#
#      AGAINST      0.646     0.681     0.663       901
#        FAVOR      0.749     0.785     0.766      1327
#      NEUTRAL      0.695     0.548     0.613       540
#
#     accuracy                          0.705      2768
#    macro avg      0.697     0.672     0.681      2768
# weighted avg      0.705     0.705     0.703      2768
# Evaluation for: LR with Multilingual Encoding : Test
#               precision    recall  f1-score   support
#
#      AGAINST      0.628     0.692     0.659       903
#        FAVOR      0.736     0.763     0.749      1329
#      NEUTRAL      0.667     0.494     0.568       542
#
#     accuracy                          0.687      2774
#    macro avg      0.677     0.650     0.659      2774
# weighted avg      0.688     0.687     0.684      2774
# Micro Average Precision :  0.6874549387166546
# Micro Average Recall :  0.6874549387166546
# Micro Average F1-Score :  0.6874549387166546
# ............................
# Macro Average Precision :  0.6770636041500167
# Macro Average Recall :  0.6498606495555518
# Macro Average F1-Score :  0.6586100912665155

# %% [markdown]
# # English BERT

# %%
per_gpu_eval_batch_size = 32
per_gpu_train_batch_size = 32
opt = 'adam'
epochs=20
epsilon=1e-08
learning_rate=1e-05
max_grad_norm=1
weight_decay=0.1

# %run src/model/BERT/BERT_EN.ipynb
# Out:
# Some weights of the model checkpoint at bert-base-cased were not used when initializing BertForSequenceClassification: ['cls.predictions.transform.LayerNorm.bias', 'cls.predictions.decoder.weight', 'cls.seq_relationship.bias', 'cls.predictions.bias', 'cls.seq_relationship.weight', 'cls.predictions.transform.dense.bias', 'cls.predictions.transform.LayerNorm.weight', 'cls.predictions.transform.dense.weight']
# - This IS expected if you are initializing BertForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at bert-base-cased and are newly initialized: ['classifier.weight', 'classifier.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of the model checkpoint at bert-base-cased were not used when initializing BertForSequenceClassification: ['cls.predictions.transform.LayerNorm.bias', 'cls.predictions.decoder.weight', 'cls.seq_relationship.bias', 'cls.predictions.bias', 'cls.seq_relationship.weight', 'cls.predictions.transform.dense.bias', 'cls.predictions.transform.LayerNorm.weight', 'cls.predictions.transform.dense.weight']
# - This IS expected if you are initializing BertForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at bert-base-cased and are newly initialized: ['classifier.weight', 'classifier.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# epoch :  1
# batch size :  32
# Training loss - 1.1698966026306152, iteration - 1/0
# Validation loss - 1.04978346824646, iteration - 1/0
# Validation loss decreased (inf --> 1.020444).  Saving model ...
#
# epoch :  2
# batch size :  32
# Training loss - 0.948732852935791, iteration - 2/0
# Validation loss - 0.8930352330207825, iteration - 2/0
# Validation loss decreased (1.020444 --> 0.901474).  Saving model ...
#
# epoch :  3
# batch size :  32
# Training loss - 0.8368880748748779, iteration - 3/0
# Validation loss - 0.734244704246521, iteration - 3/0
# Validation loss decreased (0.901474 --> 0.724258).  Saving model ...
#
# epoch :  4
# batch size :  32
# Training loss - 0.519023597240448, iteration - 4/0
# Validation loss - 0.8652003407478333, iteration - 4/0
# EarlyStopping counter: 1 out of 5
#
# epoch :  5
# batch size :  32
# Training loss - 0.4083957076072693, iteration - 5/0
# Validation loss - 0.7515373826026917, iteration - 5/0
# EarlyStopping counter: 2 out of 5
#
# epoch :  6
# batch size :  32
# Training loss - 0.3511825501918793, iteration - 6/0
# Validation loss - 0.74861079454422, iteration - 6/0
# EarlyStopping counter: 3 out of 5
#
# epoch :  7
# batch size :  32
# Training loss - 0.16693922877311707, iteration - 7/0
# Validation loss - 0.6852726936340332, iteration - 7/0
# EarlyStopping counter: 4 out of 5
#
# epoch :  8
# batch size :  32
# Training loss - 0.037223074585199356, iteration - 8/0
# Validation loss - 1.1571751832962036, iteration - 8/0
# EarlyStopping counter: 5 out of 5
# Early stopping
# Evaluation for: English BERT - Prediction
#               precision    recall  f1-score   support
#
#      AGAINST      0.742     0.665     0.701       173
#        FAVOR      0.610     0.397     0.481        63
#      NEUTRAL      0.653     0.904     0.758       104
#
#     accuracy                          0.688       340
#    macro avg      0.668     0.655     0.647       340
# weighted avg      0.690     0.688     0.678       340
# Micro Average Precision :  0.6882352941176471
# Micro Average Recall :  0.6882352941176471
# Micro Average F1-Score :  0.6882352941176471
# ............................
# Macro Average Precision :  0.668156453069907
# Macro Average Recall :  0.6551371450215381
# Macro Average F1-Score :  0.646684419697795
# label: AGAINST
# label: FAVOR
# label: NEUTRAL

# %% [markdown]
# # Spanish BERT

# %%
per_gpu_eval_batch_size = 32
per_gpu_train_batch_size = 32
opt = 'adam'
epochs=20
epsilon=1e-08
learning_rate=1e-05
max_grad_norm=1
weight_decay=0.01

# %run src/model/BERT/BERT_SP.ipynb
# Out:
# Downloading:   0%|          | 0.00/364 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/648 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/242k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/480k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/134 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/440M [00:00<?, ?B/s]
# Some weights of the model checkpoint at dccuchile/bert-base-spanish-wwm-cased were not used when initializing BertForSequenceClassification: ['cls.predictions.transform.LayerNorm.bias', 'cls.predictions.decoder.weight', 'cls.predictions.decoder.bias', 'cls.predictions.bias', 'cls.predictions.transform.dense.bias', 'cls.predictions.transform.LayerNorm.weight', 'cls.predictions.transform.dense.weight']
# - This IS expected if you are initializing BertForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at dccuchile/bert-base-spanish-wwm-cased and are newly initialized: ['bert.pooler.dense.bias', 'bert.pooler.dense.weight', 'classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of the model checkpoint at dccuchile/bert-base-spanish-wwm-cased were not used when initializing BertForSequenceClassification: ['cls.predictions.transform.LayerNorm.bias', 'cls.predictions.decoder.weight', 'cls.predictions.decoder.bias', 'cls.predictions.bias', 'cls.predictions.transform.dense.bias', 'cls.predictions.transform.LayerNorm.weight', 'cls.predictions.transform.dense.weight']
# - This IS expected if you are initializing BertForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at dccuchile/bert-base-spanish-wwm-cased and are newly initialized: ['bert.pooler.dense.bias', 'bert.pooler.dense.weight', 'classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# epoch :  1
# batch size :  104
# Training loss - 1.075226068496704, iteration - 1/0
# Validation loss - 0.6345119476318359, iteration - 1/0
# Validation loss decreased (inf --> 0.728974).  Saving model ...
#
# epoch :  2
# batch size :  104
# Training loss - 0.6800109148025513, iteration - 2/0
# Validation loss - 0.7212038040161133, iteration - 2/0
# Validation loss decreased (0.728974 --> 0.640936).  Saving model ...
#
# epoch :  3
# batch size :  104
# Training loss - 0.5467525124549866, iteration - 3/0
# Validation loss - 0.8962628841400146, iteration - 3/0
# EarlyStopping counter: 1 out of 5
#
# epoch :  4
# batch size :  104
# Training loss - 0.2427927553653717, iteration - 4/0
# Validation loss - 0.7612667679786682, iteration - 4/0
# EarlyStopping counter: 2 out of 5
#
# epoch :  5
# batch size :  104
# Training loss - 0.1376824676990509, iteration - 5/0
# Validation loss - 0.7158483266830444, iteration - 5/0
# EarlyStopping counter: 3 out of 5
#
# epoch :  6
# batch size :  104
# Training loss - 0.012083185836672783, iteration - 6/0
# Validation loss - 0.7722223997116089, iteration - 6/0
# EarlyStopping counter: 4 out of 5
#
# epoch :  7
# batch size :  104
# Training loss - 0.009101014584302902, iteration - 7/0
# Validation loss - 0.8155323266983032, iteration - 7/0
# EarlyStopping counter: 5 out of 5
# Early stopping
# Evaluation for: Spanish BERT - Prediction
#               precision    recall  f1-score   support
#
#      AGAINST      0.715     0.640     0.675       447
#        FAVOR      0.620     0.769     0.687       420
#      NEUTRAL      0.926     0.720     0.810       243
#
#     accuracy                          0.706      1110
#    macro avg      0.754     0.710     0.724      1110
# weighted avg      0.725     0.706     0.709      1110
# Micro Average Precision :  0.7063063063063063
# Micro Average Recall :  0.7063063063063063
# Micro Average F1-Score :  0.7063063063063063
# ............................
# Macro Average Precision :  0.7536291794033317
# Macro Average Recall :  0.7096777523946304
# Macro Average F1-Score :  0.724004526652419
# label: AGAINST
# label: FAVOR
# label: NEUTRAL

# %% [markdown]
# # Catalan BERT

# %%
per_gpu_eval_batch_size = 8
per_gpu_train_batch_size = 8
opt = 'adam'
epochs=20
epsilon=1e-08
learning_rate=5e-05
max_grad_norm=1
weight_decay=0.01

# %run src/model/BERT/BERT_CA.ipynb
# Out:
# Downloading:   0%|          | 0.00/1.21k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/516 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.21M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/530k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/772 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/504M [00:00<?, ?B/s]
# Some weights of the model checkpoint at PlanTL-GOB-ES/roberta-base-ca were not used when initializing RobertaForSequenceClassification: ['lm_head.bias', 'lm_head.dense.bias', 'lm_head.layer_norm.bias', 'lm_head.decoder.weight', 'lm_head.decoder.bias', 'lm_head.layer_norm.weight', 'lm_head.dense.weight']
# - This IS expected if you are initializing RobertaForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing RobertaForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of RobertaForSequenceClassification were not initialized from the model checkpoint at PlanTL-GOB-ES/roberta-base-ca and are newly initialized: ['classifier.dense.bias', 'classifier.dense.weight', 'classifier.out_proj.weight', 'classifier.out_proj.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of the model checkpoint at PlanTL-GOB-ES/roberta-base-ca were not used when initializing RobertaForSequenceClassification: ['lm_head.bias', 'lm_head.dense.bias', 'lm_head.layer_norm.bias', 'lm_head.decoder.weight', 'lm_head.decoder.bias', 'lm_head.layer_norm.weight', 'lm_head.dense.weight']
# - This IS expected if you are initializing RobertaForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing RobertaForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of RobertaForSequenceClassification were not initialized from the model checkpoint at PlanTL-GOB-ES/roberta-base-ca and are newly initialized: ['classifier.dense.bias', 'classifier.dense.weight', 'classifier.out_proj.weight', 'classifier.out_proj.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# epoch :  1
# batch size :  349
# Training loss - 1.1489548683166504, iteration - 1/0
# Validation loss - 0.31089335680007935, iteration - 1/0
# Validation loss - 1.2887684106826782, iteration - 1/100
# Validation loss decreased (inf --> 0.409584).  Saving model ...
#
# epoch :  2
# batch size :  349
# Training loss - 0.09499163180589676, iteration - 2/0
# Validation loss - 0.5756701231002808, iteration - 2/0
# Validation loss - 0.577134370803833, iteration - 2/100
# EarlyStopping counter: 1 out of 5
#
# epoch :  3
# batch size :  349
# Training loss - 0.5038755536079407, iteration - 3/0
# Validation loss - 0.2678554654121399, iteration - 3/0
# Validation loss - 0.01815280318260193, iteration - 3/100
# Validation loss decreased (0.409584 --> 0.378096).  Saving model ...
#
# epoch :  4
# batch size :  349
# Training loss - 0.022682830691337585, iteration - 4/0
# Validation loss - 0.014169414527714252, iteration - 4/0
# Validation loss - 0.3996618390083313, iteration - 4/100
# EarlyStopping counter: 1 out of 5
#
# epoch :  5
# batch size :  349
# Training loss - 0.01786334626376629, iteration - 5/0
# Validation loss - 0.007362190634012222, iteration - 5/0
# Validation loss - 0.005524430889636278, iteration - 5/100
# EarlyStopping counter: 2 out of 5
#
# epoch :  6
# batch size :  349
# Training loss - 0.6372624039649963, iteration - 6/0
# Validation loss - 1.0192081928253174, iteration - 6/0
# Validation loss - 0.01126057282090187, iteration - 6/100
# EarlyStopping counter: 3 out of 5
#
# epoch :  7
# batch size :  349
# Training loss - 0.013673152774572372, iteration - 7/0
# Validation loss - 0.0020567672327160835, iteration - 7/0
# Validation loss - 0.6108916997909546, iteration - 7/100
# EarlyStopping counter: 4 out of 5
#
# epoch :  8
# batch size :  349
# Training loss - 0.0027895320672541857, iteration - 8/0
# Validation loss - 0.01262106653302908, iteration - 8/0
# Validation loss - 1.2608267068862915, iteration - 8/100
# EarlyStopping counter: 5 out of 5
# Early stopping
#        Training Loss  Valid. Loss  Valid. Accur. Training Time Validation Time
# epoch
# 1               0.47         0.41           0.90       0:01:15         0:01:22
# 2               0.37         0.49           0.89       0:01:14         0:01:21
# 3               0.31         0.38           0.90       0:01:14         0:01:21
# 4               0.21         0.47           0.89       0:01:14         0:01:21
# 5               0.19         0.57           0.89       0:01:14         0:01:21
# 6               0.15         0.50           0.90       0:01:14         0:01:21
# 7               0.12         0.59           0.90       0:01:14         0:01:21
# Evaluation for: Catalan BERT - Prediction
#               precision    recall  f1-score   support
#
#      AGAINST      0.000     0.000     0.000        30
#        FAVOR      0.925     0.974     0.949       781
#      NEUTRAL      0.717     0.633     0.673       120
#
#     accuracy                          0.899       931
#    macro avg      0.547     0.536     0.540       931
# weighted avg      0.868     0.899     0.883       931
# Micro Average Precision :  0.8990332975295381
# Micro Average Recall :  0.8990332975295381
# Micro Average F1-Score :  0.8990332975295381
# ............................
# Macro Average Precision :  0.5472156628991952
# Macro Average Recall :  0.5359083795703513
# Macro Average F1-Score :  0.5404813923892334
# label: AGAINST
# label: FAVOR
# label: NEUTRAL

# %% [markdown]
# # French - BERT

# %%
per_gpu_eval_batch_size = 8
per_gpu_train_batch_size = 8
opt = 'adam'
epochs=20
epsilon=1e-08
learning_rate=1e-05
max_grad_norm=1
weight_decay=0.1

# %run src/model/BERT/BERT_FR.ipynb
# Out:
# Downloading:   0%|          | 0.00/83.0 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/420 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/227k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/445M [00:00<?, ?B/s]
# Some weights of the model checkpoint at dbmdz/bert-base-french-europeana-cased were not used when initializing BertForSequenceClassification: ['cls.predictions.transform.LayerNorm.bias', 'cls.predictions.decoder.weight', 'cls.predictions.decoder.bias', 'cls.seq_relationship.bias', 'cls.predictions.bias', 'cls.seq_relationship.weight', 'cls.predictions.transform.dense.bias', 'cls.predictions.transform.LayerNorm.weight', 'cls.predictions.transform.dense.weight']
# - This IS expected if you are initializing BertForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at dbmdz/bert-base-french-europeana-cased and are newly initialized: ['classifier.weight', 'classifier.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of the model checkpoint at dbmdz/bert-base-french-europeana-cased were not used when initializing BertForSequenceClassification: ['cls.predictions.transform.LayerNorm.bias', 'cls.predictions.decoder.weight', 'cls.predictions.decoder.bias', 'cls.seq_relationship.bias', 'cls.predictions.bias', 'cls.seq_relationship.weight', 'cls.predictions.transform.dense.bias', 'cls.predictions.transform.LayerNorm.weight', 'cls.predictions.transform.dense.weight']
# - This IS expected if you are initializing BertForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at dbmdz/bert-base-french-europeana-cased and are newly initialized: ['classifier.weight', 'classifier.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# epoch :  1
# batch size :  84
# Training loss - 1.1462677717208862, iteration - 1/0
# Validation loss - 0.24681788682937622, iteration - 1/0
# Validation loss decreased (inf --> 0.806175).  Saving model ...
#
# epoch :  2
# batch size :  84
# Training loss - 0.5631848573684692, iteration - 2/0
# Validation loss - 1.0030713081359863, iteration - 2/0
# Validation loss decreased (0.806175 --> 0.745704).  Saving model ...
#
# epoch :  3
# batch size :  84
# Training loss - 0.624363124370575, iteration - 3/0
# Validation loss - 0.6895978450775146, iteration - 3/0
# EarlyStopping counter: 1 out of 5
#
# epoch :  4
# batch size :  84
# Training loss - 0.29897835850715637, iteration - 4/0
# Validation loss - 2.5241177082061768, iteration - 4/0
# EarlyStopping counter: 2 out of 5
#
# epoch :  5
# batch size :  84
# Training loss - 0.015358797274529934, iteration - 5/0
# Validation loss - 0.40689998865127563, iteration - 5/0
# EarlyStopping counter: 3 out of 5
#
# epoch :  6
# batch size :  84
# Training loss - 0.004843754228204489, iteration - 6/0
# Validation loss - 0.9324371814727783, iteration - 6/0
# EarlyStopping counter: 4 out of 5
#
# epoch :  7
# batch size :  84
# Training loss - 0.0029571629129350185, iteration - 7/0
# Validation loss - 0.39616936445236206, iteration - 7/0
# EarlyStopping counter: 5 out of 5
# Early stopping
#        Training Loss  Valid. Loss  Valid. Accur. Training Time Validation Time
# epoch
# 1               0.88         0.81           0.70       0:00:12         0:00:13
# 2               0.75         0.75           0.72       0:00:13         0:00:14
# 3               0.52         0.94           0.63       0:00:12         0:00:13
# 4               0.27         1.12           0.70       0:00:12         0:00:13
# 5               0.10         1.61           0.65       0:00:12         0:00:13
# 6               0.04         1.85           0.65       0:00:12         0:00:13
# Evaluation for: French BERT - Prediction
#               precision    recall  f1-score   support
#
#      AGAINST      0.730     0.994     0.842       155
#        FAVOR      0.000     0.000     0.000        32
#      NEUTRAL      0.643     0.237     0.346        38
#
#     accuracy                          0.724       225
#    macro avg      0.458     0.410     0.396       225
# weighted avg      0.611     0.724     0.638       225
# Micro Average Precision :  0.7244444444444444
# Micro Average Recall :  0.7244444444444444
# Micro Average F1-Score :  0.7244444444444443
# ............................
# Macro Average Precision :  0.4575716542541188
# Macro Average Recall :  0.4101301641199773
# Macro Average F1-Score :  0.3958946335995517
# label: AGAINST
# label: FAVOR
# label: NEUTRAL

# %% [markdown]
# # Italian BERT

# %%
per_gpu_eval_batch_size = 8
per_gpu_train_batch_size = 8
opt = 'adam'
epochs=20
epsilon=1e-08
learning_rate=1e-05
max_grad_norm=1
weight_decay=0.1

# %run src/model/BERT/BERT_IT.ipynb
# Out:
# Downloading:   0%|          | 0.00/59.0 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/433 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/235k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/442M [00:00<?, ?B/s]
# Some weights of the model checkpoint at dbmdz/bert-base-italian-cased were not used when initializing BertForSequenceClassification: ['cls.predictions.transform.LayerNorm.bias', 'cls.predictions.decoder.weight', 'cls.seq_relationship.bias', 'cls.predictions.bias', 'cls.seq_relationship.weight', 'cls.predictions.transform.dense.bias', 'cls.predictions.transform.LayerNorm.weight', 'cls.predictions.transform.dense.weight']
# - This IS expected if you are initializing BertForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at dbmdz/bert-base-italian-cased and are newly initialized: ['classifier.weight', 'classifier.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of the model checkpoint at dbmdz/bert-base-italian-cased were not used when initializing BertForSequenceClassification: ['cls.predictions.transform.LayerNorm.bias', 'cls.predictions.decoder.weight', 'cls.seq_relationship.bias', 'cls.predictions.bias', 'cls.seq_relationship.weight', 'cls.predictions.transform.dense.bias', 'cls.predictions.transform.LayerNorm.weight', 'cls.predictions.transform.dense.weight']
# - This IS expected if you are initializing BertForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at dbmdz/bert-base-italian-cased and are newly initialized: ['classifier.weight', 'classifier.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# epoch :  1
# batch size :  63
# Training loss - 1.0905576944351196, iteration - 1/0
# Validation loss - 0.6637749671936035, iteration - 1/0
# Validation loss decreased (inf --> 0.832395).  Saving model ...
#
# epoch :  2
# batch size :  63
# Training loss - 0.8074761629104614, iteration - 2/0
# Validation loss - 0.7477869987487793, iteration - 2/0
# Validation loss decreased (0.832395 --> 0.302551).  Saving model ...
#
# epoch :  3
# batch size :  63
# Training loss - 0.19805003702640533, iteration - 3/0
# Validation loss - 0.23165038228034973, iteration - 3/0
# Validation loss decreased (0.302551 --> 0.280654).  Saving model ...
#
# epoch :  4
# batch size :  63
# Training loss - 0.00813694205135107, iteration - 4/0
# Validation loss - 0.6581262350082397, iteration - 4/0
# EarlyStopping counter: 1 out of 5
#
# epoch :  5
# batch size :  63
# Training loss - 0.0027183168567717075, iteration - 5/0
# Validation loss - 0.7383942604064941, iteration - 5/0
# EarlyStopping counter: 2 out of 5
#
# epoch :  6
# batch size :  63
# Training loss - 0.0026978205423802137, iteration - 6/0
# Validation loss - 0.8561367988586426, iteration - 6/0
# EarlyStopping counter: 3 out of 5
#
# epoch :  7
# batch size :  63
# Training loss - 0.857943058013916, iteration - 7/0
# Validation loss - 2.4901537895202637, iteration - 7/0
# EarlyStopping counter: 4 out of 5
#
# epoch :  8
# batch size :  63
# Training loss - 0.0019881518092006445, iteration - 8/0
# Validation loss - 0.001469410490244627, iteration - 8/0
# EarlyStopping counter: 5 out of 5
# Early stopping
#        Training Loss  Valid. Loss  Valid. Accur. Training Time Validation Time
# epoch
# 1               0.97         0.83           0.58       0:00:09         0:00:09
# 2               0.59         0.30           0.93       0:00:09         0:00:09
# 3               0.22         0.28           0.93       0:00:09         0:00:09
# 4               0.07         0.30           0.93       0:00:09         0:00:10
# 5               0.05         0.29           0.95       0:00:09         0:00:09
# 6               0.04         0.33           0.94       0:00:09         0:00:09
# 7               0.04         0.34           0.94       0:00:09         0:00:09
# Evaluation for: Italian BERT - Prediction
#               precision    recall  f1-score   support
#
#      AGAINST      0.970     0.990     0.980        98
#        FAVOR      0.966     0.848     0.903        33
#      NEUTRAL      0.872     0.919     0.895        37
#
#     accuracy                          0.946       168
#    macro avg      0.936     0.919     0.926       168
# weighted avg      0.947     0.946     0.946       168
# Micro Average Precision :  0.9464285714285714
# Micro Average Recall :  0.9464285714285714
# Micro Average F1-Score :  0.9464285714285714
# ............................
# Macro Average Precision :  0.935770704391394
# Macro Average Recall :  0.9190665619237048
# Macro Average F1-Score :  0.9259202094516187
# label: AGAINST
# label: FAVOR
# label: NEUTRAL

# %% [markdown]
# # MBERT

# %%
per_gpu_eval_batch_size = 32
per_gpu_train_batch_size = 32
opt = 'adam'
epochs=20
epsilon=1e-08
learning_rate=5e-05
max_grad_norm=1
weight_decay=0.01

# %run src/model/MBERT.ipynb
# Out:
# Some weights of the model checkpoint at bert-base-multilingual-cased were not used when initializing BertForSequenceClassification: ['cls.predictions.transform.LayerNorm.bias', 'cls.predictions.decoder.weight', 'cls.seq_relationship.bias', 'cls.predictions.bias', 'cls.seq_relationship.weight', 'cls.predictions.transform.dense.bias', 'cls.predictions.transform.LayerNorm.weight', 'cls.predictions.transform.dense.weight']
# - This IS expected if you are initializing BertForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at bert-base-multilingual-cased and are newly initialized: ['classifier.weight', 'classifier.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of the model checkpoint at bert-base-multilingual-cased were not used when initializing BertForSequenceClassification: ['cls.predictions.transform.LayerNorm.bias', 'cls.predictions.decoder.weight', 'cls.seq_relationship.bias', 'cls.predictions.bias', 'cls.seq_relationship.weight', 'cls.predictions.transform.dense.bias', 'cls.predictions.transform.LayerNorm.weight', 'cls.predictions.transform.dense.weight']
# - This IS expected if you are initializing BertForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at bert-base-multilingual-cased and are newly initialized: ['classifier.weight', 'classifier.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# epoch :  1
# batch size :  260
# Training loss - 1.0744004249572754, iteration - 1/0
# Validation loss - 0.3867017924785614, iteration - 1/0
# Validation loss decreased (inf --> 0.641106).  Saving model ...
#
# epoch :  2
# batch size :  260
# Training loss - 0.6599777340888977, iteration - 2/0
# Validation loss - 0.41377365589141846, iteration - 2/0
# Validation loss decreased (0.641106 --> 0.639052).  Saving model ...
#
# epoch :  3
# batch size :  260
# Training loss - 0.29418402910232544, iteration - 3/0
# Validation loss - 0.44802772998809814, iteration - 3/0
# Validation loss decreased (0.639052 --> 0.569068).  Saving model ...
#
# epoch :  4
# batch size :  260
# Training loss - 0.2085011601448059, iteration - 4/0
# Validation loss - 0.7987433075904846, iteration - 4/0
# EarlyStopping counter: 1 out of 5
#
# epoch :  5
# batch size :  260
# Training loss - 0.18828028440475464, iteration - 5/0
# Validation loss - 0.6610026359558105, iteration - 5/0
# EarlyStopping counter: 2 out of 5
#
# epoch :  6
# batch size :  260
# Training loss - 0.2492559552192688, iteration - 6/0
# Validation loss - 0.8850494027137756, iteration - 6/0
# EarlyStopping counter: 3 out of 5
#
# epoch :  7
# batch size :  260
# Training loss - 0.1984214335680008, iteration - 7/0
# Validation loss - 1.6001560688018799, iteration - 7/0
# EarlyStopping counter: 4 out of 5
#
# epoch :  8
# batch size :  260
# Training loss - 0.1387118250131607, iteration - 8/0
# Validation loss - 1.5097765922546387, iteration - 8/0
# EarlyStopping counter: 5 out of 5
# Early stopping
#        Training Loss  Valid. Loss  Valid. Accur. Training Time Validation Time
# epoch
# 1               0.79         0.64           0.72       0:03:01         0:03:22
# 2               0.61         0.64           0.73       0:03:01         0:03:22
# 3               0.51         0.57           0.77       0:03:01         0:03:22
# 4               0.38         0.65           0.78       0:03:01         0:03:22
# 5               0.26         0.71           0.77       0:03:01         0:03:22
# 6               0.17         0.92           0.77       0:03:01         0:03:22
# 7               0.11         1.32           0.74       0:03:01         0:03:22
# Evaluation for: MBERT - Prediction
#               precision    recall  f1-score   support
#
#      AGAINST      0.756     0.690     0.721       903
#        FAVOR      0.834     0.822     0.828      1329
#      NEUTRAL      0.690     0.814     0.747       542
#
#     accuracy                          0.778      2774
#    macro avg      0.760     0.775     0.765      2774
# weighted avg      0.780     0.778     0.777      2774
# Micro Average Precision :  0.777577505407354
# Micro Average Recall :  0.777577505407354
# Micro Average F1-Score :  0.777577505407354
# ............................
# Macro Average Precision :  0.7599745092740154
# Macro Average Recall :  0.7753328304977102
# Macro Average F1-Score :  0.7654457890521735
# label: AGAINST
# label: FAVOR
# label: NEUTRAL

# %% [markdown]
# # XLM

# %%
per_gpu_eval_batch_size = 16
per_gpu_train_batch_size = 16
opt = 'adam'
epochs=20
epsilon=1e-08
learning_rate=1e-05
max_grad_norm=1
weight_decay=0.01

# %run src/model/XLM.ipynb

# %% [markdown]
# # XLM-RoBERTa

# %%
per_gpu_eval_batch_size = 16
per_gpu_train_batch_size = 16
opt = 'adam'
epochs=20
epsilon=1e-08
learning_rate=1e-05
max_grad_norm=1
weight_decay=0.01

# %run src/model/XLM_RoBERTa.ipynb
# Out:
# Some weights of the model checkpoint at xlm-roberta-base were not used when initializing XLMRobertaForSequenceClassification: ['lm_head.layer_norm.bias', 'roberta.pooler.dense.bias', 'lm_head.decoder.weight', 'lm_head.dense.bias', 'lm_head.layer_norm.weight', 'lm_head.bias', 'roberta.pooler.dense.weight', 'lm_head.dense.weight']
# - This IS expected if you are initializing XLMRobertaForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing XLMRobertaForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of XLMRobertaForSequenceClassification were not initialized from the model checkpoint at xlm-roberta-base and are newly initialized: ['classifier.dense.weight', 'classifier.dense.bias', 'classifier.out_proj.weight', 'classifier.out_proj.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of the model checkpoint at xlm-roberta-base were not used when initializing XLMRobertaForSequenceClassification: ['lm_head.layer_norm.bias', 'roberta.pooler.dense.bias', 'lm_head.decoder.weight', 'lm_head.dense.bias', 'lm_head.layer_norm.weight', 'lm_head.bias', 'roberta.pooler.dense.weight', 'lm_head.dense.weight']
# - This IS expected if you are initializing XLMRobertaForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing XLMRobertaForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of XLMRobertaForSequenceClassification were not initialized from the model checkpoint at xlm-roberta-base and are newly initialized: ['classifier.dense.weight', 'classifier.dense.bias', 'classifier.out_proj.weight', 'classifier.out_proj.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# epoch :  1
# batch size :  519
# Training loss - 1.104913592338562, iteration - 1/0
# Training loss - 0.9835226535797119, iteration - 1/500
# Validation loss - 0.8798009753227234, iteration - 1/0
# Validation loss - 0.8682896494865417, iteration - 1/100
# Validation loss decreased (inf --> 0.783338).  Saving model ...
#
# epoch :  2
# batch size :  519
# Training loss - 0.6799259781837463, iteration - 2/0
# Training loss - 0.7285379767417908, iteration - 2/500
# Validation loss - 0.2670174539089203, iteration - 2/0
# Validation loss - 0.5385949611663818, iteration - 2/100
# Validation loss decreased (0.783338 --> 0.662956).  Saving model ...
#
# epoch :  3
# batch size :  519
# Training loss - 0.6278092265129089, iteration - 3/0
# Training loss - 0.9067270159721375, iteration - 3/500
# Validation loss - 0.5577724575996399, iteration - 3/0
# Validation loss - 0.6901572942733765, iteration - 3/100
# EarlyStopping counter: 1 out of 5
#
# epoch :  4
# batch size :  519
# Training loss - 0.4842938780784607, iteration - 4/0
# Training loss - 0.5936704277992249, iteration - 4/500
# Validation loss - 0.42807063460350037, iteration - 4/0
# Validation loss - 0.31544238328933716, iteration - 4/100
# Validation loss decreased (0.662956 --> 0.545017).  Saving model ...
#
# epoch :  5
# batch size :  519
# Training loss - 0.6694421172142029, iteration - 5/0
# Training loss - 0.21524246037006378, iteration - 5/500
# Validation loss - 0.42935097217559814, iteration - 5/0
# Validation loss - 0.7277209162712097, iteration - 5/100
# EarlyStopping counter: 1 out of 5
#
# epoch :  6
# batch size :  519
# Training loss - 0.21328596770763397, iteration - 6/0
